# %%
import json
import tweepy
from tweepy import OAuthHandler
 
consumer_key = '70K9Xv549k0HNty0dvTGx5Tpz'
consumer_secret = 'N6zvALwa6d5LCF0VqfCuvWfOFQkqsHblU3yw2XXZUZqWZaGH4v'
access_token = '3170648335-NVnmWZTNwsFAbgrPC1lh4vJ0CA9mipLNFXvSN6x'
access_secret = 'U7sqL0mKO4uypD6sI34DOZxAAgdvfCp1WJYhckoiUNneB'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

statuses = api.user_timeline(screen_name='@VishalKOfficial')
print(statuses)
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000025E9EE9BAC8>, _json={'created_at': 'Tue Mar 05 16:01:23 +0000 2019', 'id': 1102962320093794306, 'id_str': '1102962320093794306', 'text': 'Happy happy bday dearest @varusarath. Hav a Supa happy year ahead wit lotsa success and happiness. Gb', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'varusarath', 'name': 'varu sarathkumar', 'id': 987383070, 'id_str': '987383070', 'indices': [25, 36]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3114898232, 'id_str': '3114898232', 'name': 'Vishal', 'screen_name': 'VishalKOfficial', 'location': 'Chennai', 'description': 'Actor, Producer & fellow Human who luvs movies & anythin related to it | FB: https://t.co/1eNbhaaInv', 'url': None, 'entities': {'description': {'urls': [{'url': 'https://t.co/1eNbhaaInv', 'expanded_url': 'https://www.facebook.com/VishalKOfficial', 'display_url': 'facebook.com/VishalKOfficial', 'indices': [77, 100]}]}}, 'protected': False, 'followers_count': 963830, 'friends_count': 166, 'listed_count': 261, 'created_at': 'Sun Mar 29 08:58:18 +0000 2015', 'favourites_count': 3163, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 3438, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1085519035440148482/Mf2VX-0X_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1085519035440148482/Mf2VX-0X_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3114898232/1546559752', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 231, 'favorite_count': 5704, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 3, 5, 16, 1, 23), id=1102962320093794306, id_str='1102962320093794306', text='Happy happy bday dearest @varusarath. Hav a Supa happy year ahead wit lotsa success and happiness. Gb', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'varusarath', 'name': 'varu sarathkumar', 'id': 987383070, 'id_str': '987383070', 'indices': [25, 36]}], 'urls': []}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000025E9EE9BAC8>, _json={'id': 3114898232, 'id_str': '3114898232', 'name': 'Vishal', 'screen_name': 'VishalKOfficial', 'location': 'Chennai', 'description': 'Actor, Producer & fellow Human who luvs movies & anythin related to it | FB: https://t.co/1eNbhaaInv', 'url': None, 'entities': {'description': {'urls': [{'url': 'https://t.co/1eNbhaaInv', 'expanded_url': 'https://www.facebook.com/VishalKOfficial', 'display_url': 'facebook.com/VishalKOfficial', 'indices': [77, 100]}]}}, 'protected': False, 'followers_count': 963830, 'friends_count': 166, 'listed_count': 261, 'created_at': 'Sun Mar 29 08:5 ...
