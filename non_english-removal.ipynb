# %%
import pandas as pd
df=pd.read_csv('result_processed.csv',sep=",")
df
# Out:
#                      id                                          full text  \
# 0   1106884101104197633  Well the pics says it all   anVShall anisha s ...
# 1   1106061061487190017  Ders a time wen we look up 2 real life inciden...
# 2   1104040841503367169  Wishin my darling bro Bababaskar de very best ...
# 3   1103286626287968261   Ayogya will hit Screens Worldwide on April 19...
# 4   1102962320093794306  Happy happy bday dearest  varusarath  Hav a Su...
# 5   1101548483176091648  Welcome home dearest brother  AbhinandanVartha...
# 6   1100871685794783232  I salute u  AbhinandanMyHero  Every Indian s p...
# 7   1100718319173160960  This pic is the closest to my heart  Unbelieva...
# 8   1100439801222770688  I wish Rajini sir and kamal sir come together ...
# 9   1100032696443719680  Happy to Launch the Initiative to fight Depres...
# 10  1100010028004765696  அன்புள்ள மாணவர்களே, அழைக்கும் தூரத்தில்தான் உத...
# ...

# %%
x=(df['lang']=='ta')

# %%
x
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: lang, dtype: bool

# %%
for j in range(0,19):
    if(x[j]):
        df=df.drop(df.index[j])

# %%
df
# Out:
#                      id                                          full text  \
# 0   1106884101104197633  Well the pics says it all   anVShall anisha s ...
# 1   1106061061487190017  Ders a time wen we look up 2 real life inciden...
# 2   1104040841503367169  Wishin my darling bro Bababaskar de very best ...
# 3   1103286626287968261   Ayogya will hit Screens Worldwide on April 19...
# 4   1102962320093794306  Happy happy bday dearest  varusarath  Hav a Su...
# 5   1101548483176091648  Welcome home dearest brother  AbhinandanVartha...
# 6   1100871685794783232  I salute u  AbhinandanMyHero  Every Indian s p...
# 7   1100718319173160960  This pic is the closest to my heart  Unbelieva...
# 8   1100439801222770688  I wish Rajini sir and kamal sir come together ...
# 9   1100032696443719680  Happy to Launch the Initiative to fight Depres...
# 11  1099490094321348610  In fond remembrance of the  ironlady of TN  Ju...
# ...
